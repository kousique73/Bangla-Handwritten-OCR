# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/OCR
import sys
sys.path.append('/content/drive/MyDrive/OCR')
# Out:
# /content/drive/MyDrive/OCR

# %%
# !pip install omegaconf
# Out:
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf) (6.0.2)

# %%
# !python main.py train
# Out:
# 1480
# 1600
# Device type : cuda
# Number of batches in Train loader : 289
# Number of batches in Validation loader : 73
# Model 'BanglaOCR_20_256_4_4' is being trained ...
#
#
# Epoch: 01	learning rate : [0.0002]
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Time: 2m 16s
# Train Loss: 9197.362
# Val   Loss: 8464.553
# Model saved with Validation loss : 8464.553108946919
#
# Epoch: 02	learning rate : [0.0002]
#
# Time: 2m 14s
# Train Loss: 8645.482
# Val   Loss: 8340.095
# Model saved with Validation loss : 8340.095308486729
#
# Epoch: 03	learning rate : [0.0002]
#
# Time: 2m 16s
# Train Loss: 8497.365
# Val   Loss: 8170.466
# Model saved with Validation loss : 8170.465656437286
#
# Epoch: 04	learning rate : [0.0002]
#
# Time: 2m 15s
# Train Loss: 8360.291
# Val   Loss: 8058.197
# Model saved with Validation loss : 8058.1968994140625
#
# Epoch: 05	learning rate : [0.0002]
#
# Time: 2m 16s
# Train Loss: 8204.338
# Val   Loss: 8069.385
#
# Epoch: 06	learning rate : [0.0002]
#
# Time: 2m 15s
# Train Loss: 8020.837
# Val   Loss: 7633.961
# Model saved with Validation loss : 7633.960793691139
#
# Epoch: 07	learning rate : [0.0002]
#
# Time: 2m 14s
# Train Loss: 7835.740
# Val   Loss: 7475.500
# Model saved with Validation loss : 7475.500090298588
#
# Epoch: 08	learning rate : [0.0002]
#
# Time: 2m 14s
# Train Loss: 7647.193
# Val   Loss: 7204.575
# Model saved with Validation loss : 7204.575442797517
#
# Epoch: 09	learning rate : [0.0002]
#
# Time: 2m 15s
# Train Loss: 7461.013
# Val   Loss: 6989.961
# Model saved with Validation loss : 6989.961275283605
#
# Epoch: 10	learning rate : [0.0002]
#
# Time: 2m 14s
# Train Loss: 7279.664
# Val   Loss: 6779.033
# Model saved with Validation loss : 6779.033392501204
#
# Epoch: 11	learning rate : [0.0002]
#
# Time: 2m 14s
# Train Loss: 7107.616
# Val   Loss: 6584.621
# Model saved with Validation loss : 6584.621383039918
#
# Epoch: 12	learning rate : [0.0002]
#
# Time: 2m 15s
# Train Loss: 6949.451
# Val   Loss: 6396.002
# Model saved with Validation loss : 6396.001635407748
#
# Epoch: 13	learning rate : [0.0002]
#
# Time: 2m 15s
# Train Loss: 6808.487
# Val   Loss: 6272.890
# Model saved with Validation loss : 6272.8901199967895
#
# Epoch: 14	learning rate : [0.0002]
#
# Time: 2m 12s
# Train Loss: 6675.487
# Val   Loss: 6085.844
# Model saved with Validation loss : 6085.844453994542
#
# Epoch: 15	learning rate : [0.0002]
#
# Time: 2m 12s
# Train Loss: 6546.315
# Val   Loss: 5945.024
# Model saved with Validation loss : 5945.023507732235
#
# Epoch: 16	learning rate : [0.0002]
#
# Time: 2m 12s
# Train Loss: 6431.557
# Val   Loss: 5808.722
# Model saved with Validation loss : 5808.722198068279
#
# Epoch: 17	learning rate : [0.0002]
#
# Time: 2m 14s
# Train Loss: 6322.910
# Val   Loss: 5688.753
# Model saved with Validation loss : 5688.753280848673
#
# Epoch: 18	learning rate : [0.0002]
#
# Time: 2m 12s
# Train Loss: 6216.010
# Val   Loss: 5579.951
# Model saved with Validation loss : 5579.951064854452
#
# Epoch: 19	learning rate : [0.0002]
#
# Time: 2m 11s
# Train Loss: 6111.424
# Val   Loss: 5458.591
# Model saved with Validation loss : 5458.590941546714
#
# Epoch: 20	learning rate : [0.0002]
#
# Time: 2m 11s
# Train Loss: 6015.041
# Val   Loss: 5349.129
# Model saved with Validation loss : 5349.1291671125855
# Total training time : 0hrs. 44mins. 53s
# For inference, put the model name in 'inference_config.yaml' file
# -> model_name : BanglaOCR_20_256_4_4
#
# Optimal point : 20 epoch with Val loss 5349.1291671125855
